# %%
# 입력을 받습니다
number = input("정수 입력> ") # input()함수는 문자열로 반환
number = int(number)

if number % 2 == 0:
     print(f"{number}는 짝수입니다")
else:
     print(f"{number}는 홀수입니다")
# Out:
# 1는 홀수입니다

# %%
# 변수를 선언합니다.
score = float(input("학점 입력>"))
# score = input("학점 입력>")
# score = float(score)

# 조건문을 적용합니다
if score == 4.5:
    print(f"신")
elif (4.2 <= score < 4.5):
    print(f"교수님의 사랑")    
elif 3.5 <= score < 4.2:
    print(f"현 체제의 수호자")    
else:
    # print(f"!!!!!") 
    pass

# %%
print("# if 조건문에 0 넣기")

if 0:
    print("0은 True로 반환됩니다")
else:
    print("0은 False로 반환됩니다") # 초기화 되지 않으면 쓰레기 값이 할당되어 False로 출력
    print()

print("# if 조건문에 빈 문자열 넣기")

if "":
    print("빈 문자열은 True로 반환됩니다")
else:
    print("빈 문자열은 False로 반환됩니다")
# Out:
# # if 조건문에 0 넣기
# 0은 False로 반환됩니다
#
# # if 조건문에 빈 문자열 넣기
# 빈 문자열은 False로 반환됩니다

# %%
# pass 키워드
number = int(input("정수 입력>"))

# 조건문 사용
if number > 0:
    pass # 에러 내지마
else:
    pass
