# %% [markdown]
# # 2. 예외 고급

# %%
# try except 구문으로 예외를 처리합니다.

# 숫자를 입력받습니다.
user_input_a = input("정수 입력> ")

# 사용자 입력이 숫자로만 구성되어 있을 때
try:  # 콜론의 의미는 명령문이 다음으로 연결되어 있다
    number_input_a = int(user_input_a)
except Exception as ex: # Exception 클래스
     print("type(ex) ", type(ex))
     print("exception ", ex)
finally: # 예외가 발생되지 않았을 때
    # 출력합니다  
    print("원의 반지름:", number_input_a)
    print("원의 둘레:", 2 * 3.14 * number_input_a)
    print("원의 넓이:", 3.14 * number_input_a * number_input_a)
# Out:
# type(ex)  <class 'ValueError'>
# exception  invalid literal for int() with base 10: 'gksrmf'
# 원의 반지름: 10
# 원의 둘레: 62.800000000000004
# 원의 넓이: 314.0

# %%
# 모든 예외 구문과 예외 객체 처리

# 변수를 선언합니다.
list_number = [52, 273, 32, 72, 100]

# try except 구문으로 예외를 처리합니다.
try:
    number_input_a = int(input("정수 입력 >"))
except ValueError as ex:
    # ValueError가 발생하는 경우
    print("정수를 입력해 주세요!")
    print("type(ex) ", type(ex))
else:
    pass
finally:
    pass
# Out:
# 정수를 입력해 주세요!
# type(ex)  <class 'ValueError'>

# %%
# 모든 예외 구문과 예외 객체 처리

# 변수를 선언합니다.
list_number = [52, 273, 32, 72, 100]

# try except 구문으로 예외를 처리합니다.
try:
    number_input_a = int(input("정수 입력 >"))  # ValueError 
    # 리스트의 요소를 출력합니다.
    print("{}번째 요소: {}".format(number_input_a, list_number[number_input_a])) # IndexError

    예외.발생해주세요()  # except Exception에서 NameError 발생

# except Exception as ex:  # except 순서와 상관 없이 모든 예외 처리가 가능(우선) -> except의 맨 마지막에 정의되어야 함
#     print("미리 파악하지 못한 예외가 발생했습니다.")
#     print("type(ex)", type(ex))

except ValueError as ex:  # 수행 후 fianlly 수행함, Exception의 자식 클래스
    # 예외 객체 출력
    print("type(ex) ", type(ex))
    print("exception:", ex)

except IndexError as ex:
    # IndexError가 발생하는 경우
    print("리스트의 인덱스를 벗어났어요")
    print("type(ex)", type(ex))

except NameError as ex:
    print("이름이 존재하지 않은 변수를 사용하고 있어요")
    print("type() ", type(ex))

except Exception as ex:  # except 순서와 상관 없이 모든 예외 처리가 가능(우선) -> except의 맨 마지막에 정의되어야 함,
    print("미리 파악하지 못한 예외가 발생했습니다.")
    print("type(ex)", type(ex))

else:  # except else는 정상 케이스
    pass
finally:
    pass

print("\n프로그램이 종료되었습니다.")
# Out:
# 미리 파악하지 못한 예외가 발생했습니다.
# type(ex) <class 'ValueError'>
#
# 프로그램이 종료되었습니다.

# %%
# 강제 예외 발생
# 입력
number = int(input("정수 입력 >"))

# 조건문 사용
if number > 0:
    # 양수일 때: 아직 미구현 상태입니다.
    # pass
    raise NotImplementedError
else:
    # 양수일 때: 아직 미구현 상태입니다.
    # pass
    raise NotImplementedError
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[27], line 9
#       5 # 조건문 사용
#       6 if number > 0:
#       7     # 양수일 때: 아직 미구현 상태입니다.
#       8     # pass
# ----> 9     raise NotImplementedError
#      10 else:
#      11     # 양수일 때: 아직 미구현 상태입니다.
#      12     # pass
#
# NotImplementedError:
