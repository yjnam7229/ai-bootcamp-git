# %% [markdown]
# ### 히든 레이어 추가

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
(train_input, train_target), (test_input, test_target) \
    = tf.keras.datasets.fashion_mnist.load_data()

# %%
# 정규화
train_scaled = train_input / 255.0
test_scaled = test_input / 255.0

# 입력데이터: 2 dim -> 1 dim 변환
train_scaled = train_scaled.reshape(-1, 28 * 28) # 3차원 -> 2차원
train_scaled.shape
# Out:
# (60000, 784)

# %%
# 신경망 구성

model = tf.keras.Sequential()

# %%
# 입력 레이어
model.add(tf.keras.Input(shape=(784,)))

# 출력 레이 추가
# 2개 히든 레이어 추가
# 활성화 함수 sigmoid
model.add(tf.keras.layers.Dense(
    units=50,
    activation='sigmoid',
    name='hidden1'
))

model.add(tf.keras.layers.Dense(
    units=100,
    activation='sigmoid',
    name='hidden2'))

# 최종 출력단, softmax 알고리즘
model.add(tf.keras.layers.Dense(
    units=10,
    activation='softmax',
    name='output'))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ hidden1 (Dense)                 │ (None, 50)             │        39,250 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden2 (Dense)                 │ (None, 100)            │         5,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 45,360 (177.19 KB)
#  Trainable params: 45,360 (177.19 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
loss = model.fit(train_scaled, train_target, epochs=100)
# Out:
# Epoch 1/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 788us/step - accuracy: 0.3700 - loss: 2.1638
# Epoch 2/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - accuracy: 0.5615 - loss: 1.5634
# Epoch 3/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 789us/step - accuracy: 0.6339 - loss: 1.1542
# Epoch 4/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 789us/step - accuracy: 0.6775 - loss: 0.9537
# Epoch 5/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 792us/step - accuracy: 0.7067 - loss: 0.8369
# Epoch 6/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 804us/step - accuracy: 0.7293 - loss: 0.7590
# Epoch 7/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 800us/step - accuracy: 0.7434 - loss: 0.7033
# Epoch 8/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 804us/step - accuracy: 0.7574 - loss: 0.6618
# Epoch 9/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 771us/step - accuracy: 0.7680 - loss: 0.6293
# Epoch 10/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - accuracy: 0.7779 - loss: 0.6027
# Epoch 11/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 786us/step - accuracy: 0.7882 - loss: 0.5802
# Epoch 12/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 800us/step - accuracy: 0.7972 - loss: 0.5603
# Epoch 13/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 781us/step - accuracy: 0.8046 - loss: 0.5431
# Epoch 14/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 801us/step - accuracy: 0.8123 - loss: 0.5278
# Epoch 15/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 789us/step - accuracy: 0.8180 - loss: 0.5142
# Epoch 16/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 789us/step - accuracy: 0.8227 - loss: 0.5024
# Epoch 17/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 792us/step - accuracy: 0.8270 - loss: 0.4918
# Epoch 18/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 792us/step - accuracy: 0.8307 - loss: 0.4825
# Epoch 19/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 792us/step - accuracy: 0.8326 - loss: 0.4744
# Epoch 20/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 790us/step - accuracy: 0.8355 - loss: 0.4670
# Epoch 21/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 788us/step - accuracy: 0.8382 - loss: 0.4600
# Epoch 22/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 795us/step - accuracy: 0.8394 - loss: 0.4538
# Epoch 23/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 805us/step - accuracy: 0.8413 - loss: 0.4480
# Epoch 24/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 801us/step - accuracy: 0.8439 - loss: 0.4425
# Epoch 25/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 790us/step - accuracy: 0.8448 - loss: 0.4374
# Epoch 26/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 799us/step - accuracy: 0.8471 - loss: 0.4328
# Epoch 27/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 800us/step - accuracy: 0.8483 - loss: 0.4282
# Epoch 28/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 804us/step - accuracy: 0.8485 - loss: 0.4240
# Epoch 29/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 799us/step - accuracy: 0.8503 - loss: 0.4200
# Epoch 30/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 784us/step - accuracy: 0.8518 - loss: 0.4161
# Epoch 31/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 798us/step - accuracy: 0.8530 - loss: 0.4128
# Epoch 32/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 795us/step - accuracy: 0.8542 - loss: 0.4091
# Epoch 33/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 793us/step - accuracy: 0.8555 - loss: 0.4060
# Epoch 34/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 792us/step - accuracy: 0.8565 - loss: 0.4026
# Epoch 35/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 788us/step - accuracy: 0.8574 - loss: 0.3995
# Epoch 36/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 800us/step - accuracy: 0.8583 - loss: 0.3966
# Epoch 37/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 800us/step - accuracy: 0.8598 - loss: 0.3939
# Epoch 38/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 807us/step - accuracy: 0.8609 - loss: 0.3912
# Epoch 39/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 790us/step - accuracy: 0.8615 - loss: 0.3885
# Epoch 40/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 800us/step - accuracy: 0.8616 - loss: 0.3862
# Epoch 41/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 789us/step - accuracy: 0.8634 - loss: 0.3838
# Epoch 42/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 786us/step - accuracy: 0.8639 - loss: 0.3813
# Epoch 43/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 805us/step - accuracy: 0.8648 - loss: 0.3791
# Epoch 44/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 797us/step - accuracy: 0.8652 - loss: 0.3772
# Epoch 45/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 790us/step - accuracy: 0.8664 - loss: 0.3746
# Epoch 46/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 796us/step - accuracy: 0.8666 - loss: 0.3725
# Epoch 47/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 799us/step - accuracy: 0.8672 - loss: 0.3706
# Epoch 48/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 795us/step - accuracy: 0.8678 - loss: 0.3686
# Epoch 49/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 781us/step - accuracy: 0.8689 - loss: 0.3670
# Epoch 50/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 778us/step - accuracy: 0.8696 - loss: 0.3650
# Epoch 51/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 793us/step - accuracy: 0.8700 - loss: 0.3634
# Epoch 52/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 805us/step - accuracy: 0.8704 - loss: 0.3613
# Epoch 53/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 781us/step - accuracy: 0.8716 - loss: 0.3597
# Epoch 54/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 787us/step - accuracy: 0.8722 - loss: 0.3581
# Epoch 55/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 782us/step - accuracy: 0.8728 - loss: 0.3563
# Epoch 56/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 786us/step - accuracy: 0.8737 - loss: 0.3551
# Epoch 57/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 809us/step - accuracy: 0.8734 - loss: 0.3534
# Epoch 58/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 799us/step - accuracy: 0.8745 - loss: 0.3515
# Epoch 59/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 798us/step - accuracy: 0.8751 - loss: 0.3504
# Epoch 60/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 790us/step - accuracy: 0.8750 - loss: 0.3488
# Epoch 61/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 818us/step - accuracy: 0.8759 - loss: 0.3475
# Epoch 62/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 807us/step - accuracy: 0.8757 - loss: 0.3458
# Epoch 63/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 797us/step - accuracy: 0.8766 - loss: 0.3448
# Epoch 64/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 801us/step - accuracy: 0.8778 - loss: 0.3433
# Epoch 65/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 797us/step - accuracy: 0.8778 - loss: 0.3419
# Epoch 66/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 815us/step - accuracy: 0.8783 - loss: 0.3407
# Epoch 67/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 822us/step - accuracy: 0.8788 - loss: 0.3394
# Epoch 68/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 807us/step - accuracy: 0.8792 - loss: 0.3379
# Epoch 69/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 813us/step - accuracy: 0.8797 - loss: 0.3370
# Epoch 70/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 808us/step - accuracy: 0.8800 - loss: 0.3355
# Epoch 71/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 808us/step - accuracy: 0.8806 - loss: 0.3348
# Epoch 72/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 812us/step - accuracy: 0.8811 - loss: 0.3337
# Epoch 73/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 797us/step - accuracy: 0.8810 - loss: 0.3325
# Epoch 74/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 811us/step - accuracy: 0.8821 - loss: 0.3310
# Epoch 75/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 805us/step - accuracy: 0.8821 - loss: 0.3301
# Epoch 76/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 805us/step - accuracy: 0.8825 - loss: 0.3289
# Epoch 77/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 804us/step - accuracy: 0.8833 - loss: 0.3280
# Epoch 78/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 828us/step - accuracy: 0.8833 - loss: 0.3268
# Epoch 79/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 799us/step - accuracy: 0.8841 - loss: 0.3259
# Epoch 80/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 802us/step - accuracy: 0.8841 - loss: 0.3250
# Epoch 81/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 799us/step - accuracy: 0.8845 - loss: 0.3236
# Epoch 82/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 796us/step - accuracy: 0.8855 - loss: 0.3227
# Epoch 83/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 806us/step - accuracy: 0.8855 - loss: 0.3217
# Epoch 84/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 786us/step - accuracy: 0.8855 - loss: 0.3209
# Epoch 85/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 798us/step - accuracy: 0.8853 - loss: 0.3200
# Epoch 86/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 805us/step - accuracy: 0.8861 - loss: 0.3190
# Epoch 87/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 803us/step - accuracy: 0.8868 - loss: 0.3178
# Epoch 88/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 806us/step - accuracy: 0.8863 - loss: 0.3173
# Epoch 89/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 811us/step - accuracy: 0.8875 - loss: 0.3161
# Epoch 90/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 801us/step - accuracy: 0.8878 - loss: 0.3153
# Epoch 91/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 809us/step - accuracy: 0.8880 - loss: 0.3144
# Epoch 92/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 801us/step - accuracy: 0.8886 - loss: 0.3138
# Epoch 93/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 800us/step - accuracy: 0.8879 - loss: 0.3124
# Epoch 94/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 808us/step - accuracy: 0.8887 - loss: 0.3120
# Epoch 95/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 804us/step - accuracy: 0.8894 - loss: 0.3109
# Epoch 96/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 819us/step - accuracy: 0.8895 - loss: 0.3099
# Epoch 97/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 818us/step - accuracy: 0.8897 - loss: 0.3094
# Epoch 98/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 808us/step - accuracy: 0.8891 - loss: 0.3083
# Epoch 99/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 809us/step - accuracy: 0.8906 - loss: 0.3074
# Epoch 100/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 802us/step - accuracy: 0.8907 - loss: 0.3066

# %%
test_scaled = test_scaled.reshape(-1, 28*28)

model.evaluate(test_scaled, test_target)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step - accuracy: 0.8684 - loss: 0.3680
# [0.3680075705051422, 0.868399977684021]
