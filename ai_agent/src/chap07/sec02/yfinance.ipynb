# %%
import yfinance as yf

# Microsoft (MSFT)에 대한 Ticker 객체 생성
msft = yf.Ticker("MSFT") # AMZN/META/

# Ticker 객체에 대한 정보 출력 (.py에서 실행할 때는 print(msft.info)로 사용)
display(msft.info)
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
# 최근 5일간의 주가 정보 확인
hist = msft.history(period='5d')  
display(hist)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2026-08-11 00:00:00-04:00  504.329987  505.329987  499.549988  503.809998
# 2026-08-12 00:00:00-04:00  499.989990  501.500000  491.519989  492.429993
# 2026-08-13 00:00:00-04:00  493.269989  501.339996  493.010010  496.880005
# 2026-08-14 00:00:00-04:00  496.359985  500.010010  493.920013  495.399994
# 2026-08-17 00:00:00-04:00         NaN         NaN         NaN         NaN
#
#                              Volume  Dividends  Stock Splits
# Date
# 2026-08-11 00:00:00-04:00  23049800        0.0           0.0
# 2026-08-12 00:00:00-04:00  29001500        0.0           0.0
# 2026-08-13 00:00:00-04:00  23039000        0.0           0.0
# 2026-08-14 00:00:00-04:00  16217600        0.0           0.0
# 2026-08-17 00:00:00-04:00  28250867        0.0           0.0

# %%
# 추천 정보 출력
# 해당 종목에 대한 애널리스트들의 분석 결과
msft.recommendations

# -1m : 한달전
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m         14   39     3     0           0
# 1    -1m         14   40     3     0           0
# 2    -2m         13   41     3     0           0
# 3    -3m         12   41     3     0           0
