# %%
from langchain_community.document_loaders import TextLoader, PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# 1. AI 용어 로드(텍스트 파일)
ai_loader = TextLoader('./data/Python_AI_Glossary_Guide.txt', encoding='utf-8')
ai_docs = ai_loader.load()

# 2. 펫보험 약관 로드 (PDF 파일)
insurance_loader = PyPDFLoader('./data/meritz_pet_insurance.pdf')
insurance_docs = insurance_loader.load()

# %%
print(f'AI 용어: {len(ai_docs)}개 문서 로드')
print(f'메타데이터 내용: {ai_docs[0].metadata}')
print(f'내용: {ai_docs[0].page_content[:50]}...')
print()
print(f'펫보험 약관: {len(insurance_docs)}개 문서 로드')
print(f'메타데이터 내용: {insurance_docs[0].metadata}')
print(f'내용: {insurance_docs[0].page_content[:50]}...')

# print(ai_docs)
# Out:
# AI 용어: 1개 문서 로드
# 메타데이터 내용: {'source': './data/Python_AI_Glossary_Guide.txt'}
# 내용: 파이썬 기초 개념
# ---
# OOP (Object-Oriented Programming)
# 정의...
#
# 펫보험 약관: 28개 문서 로드
# 메타데이터 내용: {'producer': 'iLovePDF', 'creator': 'PyPDF', 'creationdate': '2026-08-25T07:28:04+09:00', 'moddate': '2026-08-25T07:28:04+09:00', 'pdfversion': '1.4', 'source': './data/meritz_pet_insurance.pdf', 'total_pages': 28, 'page': 0, 'page_label': '1'}
# 내용: 장기 약관_제2024-8호
# 반려동물 실손의료비보험
# (무)펫퍼민트 Puppy&Family보험...

# %%
# 문서 청킹하기
# 청킹 설정: 200자씩 자르고, 20자는 겹치게(overlap) 설정, 하이퍼파라미터
# 질문과의 높은 연관성(specificity)과 답변에 필요한 충분한 맥락(context preservation)사이의 균형을 맞추는 일
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=200,     # 청크 크기
    chunk_overlap=20    # 청크 겹침
)
# AI 용어 청킹
ai_chunks = text_splitter.split_documents(ai_docs)

# 팻 보험 청킹
insurance_chunks = text_splitter.split_documents(insurance_docs)

# 청킹 결과 출력
print(f'AI 용어 청킹: {len(ai_chunks)}개 청크로 분할')
print(ai_chunks[0].page_content)
print()
print(f'팻 보험: {len(insurance_chunks)}개 청크로 분할')
print(insurance_chunks[0].page_content)

# %%
# 메타데이터로 데이터 구분하기(★★★★★★빠른 검색을 위함)
# 태그 정보들을 토대로 검색의 품질을 향상시킬 수 있게 됨
# 메타데이터 추가(딕셔너리 형태인 metadata 속성에 새로운 키와 값을 추가) 
# 반복문을 사용해 각 청크들의 source_type과 category 속성에 동일한 값들을 할당

# 1. AI 용어 청크에 메타데이터 추가
for chunk in ai_chunks:
    chunk.metadata['source_type'] = 'glossary'
    chunk.metadata['catagory'] = 'AI & Python'

# 2. 팻 보험 청크에 메타데이터 추가
for chunk in insurance_chunks:
    chunk.metadata['source_type'] = 'insurance'
    chunk.metadata['catagory'] = 'Pet Insurance'

print(f'{ai_chunks[0].metadata}')
print(f'{insurance_chunks[0].metadata}')
# Out:
# {'source': './data/Python_AI_Glossary_Guide.txt', 'source_type': 'glossary', 'catagory': 'AI & Python'}
# {'producer': 'iLovePDF', 'creator': 'PyPDF', 'creationdate': '2026-08-25T07:28:04+09:00', 'moddate': '2026-08-25T07:28:04+09:00', 'pdfversion': '1.4', 'source': './data/meritz_pet_insurance.pdf', 'total_pages': 28, 'page': 0, 'page_label': '1', 'source_type': 'insurance', 'catagory': 'Pet Insurance'}
