# %%
# !pip install streamlit

# %%
# %%writefile my_first_app.py
import streamlit as str

str.title('안녕하세요 Streamlit!')
str.write('이것은 나의 첫 번째 Streamlit 애플리케이션입니다.')
# Out:
# Overwriting my_first_app.py

# %%
# !streamlit run my_first_app.py
